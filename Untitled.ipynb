# %% [markdown]
# Goupes: ouiam kamili
#         yahya charif
#         essaoud oumaima
#         taha benhima

# %%
# importer les bibliotheques
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#lire la base de donnee
tips=pd.read_csv('disney.csv')

# %%
tips
# Out:
#      show_id     type                                             title  \
# 0         s1    Movie  Duck the Halls: A Mickey Mouse Christmas Special
# 1         s2    Movie                            Ernest Saves Christmas
# 2         s3    Movie                      Ice Age: A Mammoth Christmas
# 3         s4    Movie                        The Queen Family Singalong
# 4         s5  TV Show                             The Beatles: Get Back
# ...      ...      ...                                               ...
# 1445   s1446    Movie                          X-Men Origins: Wolverine
# 1446   s1447    Movie    Night at the Museum: Battle of the Smithsonian
# 1447   s1448    Movie                                   Eddie the Eagle
# 1448   s1449    Movie                              Bend It Like Beckham
# 1449   s1450    Movie             Captain Sparky vs. The Flying Saucers
#
#                                director  \
# 0     Alonso Ramirez Ramos, Dave Wasson
# ...

# %%
type (tips)
# Out:
# pandas.core.frame.DataFrame

# %%
director_data = {
    'Director': ['Alonso Ramirez Ramos', 'John Cherry', 'Karen Disher', 'Hamish Hamilton', 'Nan'],
    'Popularity': [90, 88, 85, 82, 80]  # Les valeurs de popularité sont fictives
}

# Exemple de données fictives pour les acteurs
actor_data = {
    'Actor': ['Chris Diamantopoulos', '', 'Jim Varney', 'Noelle Parker', 'Douglas Seal', 'Mayur More', 'Mark Ruffalo', 'Jesse Eisenber', 'Tim Allen', 'Vicky Kaushalp'],
    'Rating': [95, 92, 90, 88, 87, 85, 84, 82, 80, 78]  # Les valeurs de notation sont fictives
}

# Créer des DataFrames à partir des données
top_directors = pd.DataFrame(director_data)
top_actors = pd.DataFrame(actor_data)

# Tracer des graphiques à barres pour les réalisateurs et les acteurs
plt.figure(figsize=(12, 6))

# Top 5 des réalisateurs
plt.subplot(1, 2, 1)
sns.barplot(x='Director', y='Popularity', data=top_directors, palette='magma')
plt.title('Top 5 des réalisateurs')
plt.xlabel('Réalisateur')
plt.ylabel('Popularité')
plt.xticks(rotation=45)

# Top 10 des acteurs
plt.subplot(1, 2, 2)
sns.barplot(x='Actor', y='Rating', data=top_actors, palette='magma')
plt.title('Top 10 des acteurs')
plt.xlabel('Acteur')
plt.ylabel('Notation')
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %%
data = {
    'Category': ['Action', 'Comedy', 'Drama', 'Thriller', 'Sci-Fi'],
    'Popularity': [85, 72, 68, 64, 60]  # Les valeurs de popularité sont fictives
}

top_categories = pd.DataFrame(data)

# Tracer un graphique à barres avec Seaborn
plt.figure(figsize=(10, 6))
sns.barplot(x='Category', y='Popularity', data=top_categories, palette='viridis')
plt.title('Top 5 des meilleures catégories')
plt.xlabel('Catégorie')
plt.ylabel('Popularité')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
tv_series_data = {
    'Title': ['The Beatles:get back', 'Hawkeye	', 'port protection alaska', 'secrets of the zoo:tampa', 'Dr: Oakley ,yukon vet'],
    'Seasons': [1, 1, 2, 2, 2]
}

# Créer un DataFrame à partir des données
tv_series = pd.DataFrame(tv_series_data)

# Trier les séries télévisées par le nombre de saisons (du plus grand au plus petit)
tv_series_sorted = tv_series.sort_values(by='Seasons', ascending=False).head(5)

# Tracer un graphique à barres pour les cinq meilleures séries télévisées avec le plus grand nombre de saisons
plt.figure(figsize=(10, 6))
sns.barplot(x='Title', y='Seasons', data=tv_series_sorted, palette='pastel')
plt.title('Top 5 des séries télévisées avec le plus grand nombre de saisons')
plt.xlabel('Série télévisée')
plt.ylabel('Nombre de saisons')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_7948\848790648.py:19: UserWarning: Glyph 9 (	) missing from current font.
#   plt.tight_layout()
# C:\Users\hp\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# Vos textes
texts = [
    "Join Mickel and the gang as they duck the halls...",
    "Santa Claus passes his magic bag to a new St. Nic...",
    "Sid the Sloth is on Santa's naughty list...",
    "This is real life , not just fantasy!...",
    "A three-part documentary from Peter Jacques capturing a moment in music history with the Beatles...",
    "An inside look at the legendry life of adventurer Jacques-yves cousteau ...",
    "Clint Barton/Hawkeye must team up with skilled archer Kate Bishop to unravel a criminal conspiracy...",
    "Resident of port Protection must cobat volatile conditions to survive and thrive in Alaska...",
    "A day in the life at ZooTampa is anything but ordinary. It's extraordunary..." ,
    "Celebrate the holiday season with all favorite Muppets..." ,
]

vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(texts)

# Calcul des similarités cosinus
cosine_similarities = cosine_similarity(tfidf_matrix, tfidf_matrix)

# Affichage des paires de textes similaires
for i in range(len(texts)):
    for j in range(i+1, len(texts)):
        print(f"Similarité entre texte {i+1} et texte {j+1}: {cosine_similarities[i][j]}")
# Out:
# Similarité entre texte 1 et texte 2: 0.0
# Similarité entre texte 1 et texte 3: 0.07551330312238375
# Similarité entre texte 1 et texte 4: 0.0
# Similarité entre texte 1 et texte 5: 0.055578574494231266
# Similarité entre texte 1 et texte 6: 0.061151253988269885
# Similarité entre texte 1 et texte 7: 0.0
# Similarité entre texte 1 et texte 8: 0.06923731426130596
# Similarité entre texte 1 et texte 9: 0.062214015993112555
# Similarité entre texte 1 et texte 10: 0.07396682590421416
# Similarité entre texte 2 et texte 3: 0.09261308906974118
# Similarité entre texte 2 et texte 4: 0.0
# Similarité entre texte 2 et texte 5: 0.0
# Similarité entre texte 2 et texte 6: 0.0
# Similarité entre texte 2 et texte 7: 0.048838284860567696
# Similarité entre texte 2 et texte 8: 0.05183909261879586
# Similarité entre texte 2 et texte 9: 0.0
# Similarité entre texte 2 et texte 10: 0.0
# Similarité entre texte 3 et texte 4: 0.08736926775186009
# Similarité entre texte 3 et texte 5: 0.03231378341575312
# ...

# %%
# Charger le fichier CSV localement
file_path = "disney.csv"
data = pd.read_csv(file_path)

print("Aperçu des données :")
print(data.head())

# 3. Analyser les statistiques descriptives
print("\nStatistiques descriptives :")
print(data.describe())

# 4. Visualiser les données (exemple : histogramme)
import matplotlib.pyplot as plt

data["release_year"].hist(bins=20)
plt.title("Distribution des années de sortie")
plt.xlabel("Année de sortie")
plt.ylabel("Nombre de contenus")
plt.show()

# 5. Identifier des tendances ou des motifs
# Par exemple, compter le nombre de contenus par type
content_types_count = data["type"].value_counts()
print("\nNombre de contenus par type :")
print(content_types_count)
# Out:
# Aperçu des données :
#   show_id     type                                             title  \
# 0      s1    Movie  Duck the Halls: A Mickey Mouse Christmas Special
# 1      s2    Movie                            Ernest Saves Christmas
# 2      s3    Movie                      Ice Age: A Mammoth Christmas
# 3      s4    Movie                        The Queen Family Singalong
# 4      s5  TV Show                             The Beatles: Get Back
#
#                             director  \
# 0  Alonso Ramirez Ramos, Dave Wasson
# 1                        John Cherry
# 2                       Karen Disher
# 3                    Hamish Hamilton
# 4                                NaN
#
#                                                 cast        country  \
# 0  Chris Diamantopoulos, Tony Anselmo, Tress MacN...            NaN
# 1           Jim Varney, Noelle Parker, Douglas Seale            NaN
# 2  Raymond Albert Romano, John Leguizamo, Denis L...  United States
# ...
